# %%
import math
A = 67
B = -23

def Straight(number): # Функци преобразования числа number из 10-чной в p-тую систему счисления
    number_save = abs(number)
    number_list = [] # Массивчик для циферок
    while number_save > 1:  # Пока не равно 0 или 1
        number_list.append(math.trunc(number_save % 2))  # Добавляем остаток от деления на p - систему счисления
        number_save = number_save / 2 # Делим на систему счисления
    number_list.reverse()  # Переворачиваем
    
    if len(number_list) < 7:
        for i in range(7 - len(number_list)):
            number_list.insert(0, '0')
    if number >= 0:
        number_list.insert(0, '.')
        number_list.insert(0, '0')
    else:
        number_list.insert(0, '.')
        number_list.insert(0, '1')
        
    return "".join(map(str, number_list)) # Преобразовываем в красивую строку


def rev_code(number):
    number_save = abs(number)
    number_list = [] # Массивчик для циферок
    while number_save > 1:  # Пока не равно 0 или 1
        number_list.append(math.trunc(number_save % 2))  # Добавляем остаток от деления на p - систему счисления
        number_save = number_save / 2 # Делим на систему счисления
    number_list.reverse()  # Переворачиваем
    
    if len(number_list) < 7:
        for i in range(7 - len(number_list)):
            number_list.insert(0, '0')
    if number >= 0:
        number_list.insert(0, '.')
        number_list.insert(0, '0')
    else:
        for i in range(len(number_list)):
            if number_list[i] == 1:
                number_list[i] = '0'
            else:
                number_list[i] = '1'
        number_list.insert(0, '.')
        number_list.insert(0, '1')
        
    return "".join(map(str, number_list)) # Преобразовываем в красивую строку


def dop_code(number):
    print(bin(~int(number)))
#     number_save = abs(number)
#     number_list = [] # Массивчик для циферок
#     while number_save > 1:  # Пока не равно 0 или 1
#         number_list.append(math.trunc(number_save % 2))  # Добавляем остаток от деления на p - систему счисления
#         number_save = number_save / 2 # Делим на систему счисления
#     number_list.reverse()  # Переворачиваем
#     print(number_list)
#     number_list = ''.join(map(str, number_list))
#     print(number_list)
#     number_list = int(number_list)
#     print(bin(number_list))
#     if len(number_list) < 7:
#         for i in range(7 - len(number_list)):
#             number_list.insert(0, 0)
#     if number >= 0:
#         number_list.insert(0, '.')
#         number_list.insert(0, 0)
#     else:
#         for i in range(len(number_list)):
#             if number_list[i] == 1:
#                 number_list[i] = 0
#             else:
#                 number_list[i] = 1
#         number_list.insert(0, '.')
#         number_list.insert(0, 1)
#     return number_list # Преобразовываем в красивую строку


print(Straight(A))
print(Straight(B))
print(Straight(-A))
print(Straight(-B))

print('\n\n\n')

print(rev_code(A))
print(rev_code(B))
print(rev_code(-A))
print(rev_code(-B))


print('\n\n\n')

print(dop_code(A))
print(dop_code(B))
print(dop_code(-A))
print(dop_code(-B))
# Out:
# 0.1000011
# 1.0010111
# 1.1000011
# 0.0010111
#
#
#
#
# 0.1000011
# 1.1101000
# 1.0111100
# 0.0010111
#
#
#
#
# -0b1000100
# None
# 0b10110
# None
# 0b1000010
# None
# -0b11000
# None
